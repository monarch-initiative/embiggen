# %%
from embiggen.embedders import SecondOrderLINETensorFlow
from grape.datasets.linqs import Cora, get_words_data
from embiggen import GraphVisualizer

# %%
graph, _ = get_words_data(Cora())

# %%
model = SecondOrderLINETensorFlow()
# Out:
# /Users/lucacappelletti/github/embiggen/embiggen/utils/tensorflow_utils.py:182: UserWarning: It was neither possible to detect GPUs nor GPU drivers of any kind on your system (neither CUDA or ROCM).
# The model will proceed with trainining, but it will be significantly slower than what would be possible with GPU acceleration.
#   "It was neither possible to detect GPUs nor GPU drivers "

# %%
embedding = model.fit_transform(graph, )
# Out:
# 2022-06-15 11:23:07.336122: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]

# %%
vis = GraphVisualizer(graph)

# %%
vis.fit_nodes(embedding.get_node_embedding_from_index(1))

# %%
vis.plot_node_types()
# Out:
# <p style="text-align: justify; word-break: break-all;"><i>Node types</i>: 'Neural Networks' in blue, 'Probabilistic Methods' in orange, 'Genetic Algorithms' in red, 'Theory' in cyan, 'Case Based' in green, 'Reinforcement Learning' in yellow, and 'Rule Learning' in purple. The node types cora do not appear to form recognizable clusters (Balanced accuracy: 52.19% ± 1.29%) The separability consideration  derive from evaluating a Decision Tree trained on five Monte Carlo holdouts, with a 70/30 split between training and test sets..</p>
