# %%
from embiggen.embedders import FirstOrderLINEEnsmallen
from grape.datasets.linqs import Cora, get_words_data
from embiggen import GraphVisualizer

# %%
graph, _ = get_words_data(Cora())

# %%
model = FirstOrderLINEEnsmallen(
    epochs=10000,
    learning_rate=0.001
)

# %%
embedding = model.fit_transform(graph, )

# %%
embedding = embedding.get_node_embedding_from_index(0)

# %%
vis = GraphVisualizer(graph, decomposition_kwargs=dict(metric="cosine"))
vis.fit_nodes(embedding)

# %%
vis.plot_node_types()
# Out:
# <p style="text-align: justify; word-break: break-all;"><i>Node types</i>: 'Neural Networks' in blue, 'Probabilistic Methods' in orange, 'Genetic Algorithms' in red, 'Theory' in cyan, 'Case Based' in green, 'Reinforcement Learning' in yellow, and 'Rule Learning' in purple. The node types cora do not appear to form recognizable clusters (Balanced accuracy: 14.43% ± 0.38%) The separability consideration  derive from evaluating a Decision Tree trained on five Monte Carlo holdouts, with a 70/30 split between training and test sets..</p>
